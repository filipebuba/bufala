# %%
# !pip install timm --upgrade
# !pip install accelerate
# !pip install git+https://github.com/huggingface/transformers.git
# add more to make demo
# !pip install gradio

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 🔧 Resolução do Erro de Autenticação do Kaggle
#
# ## ❌ Problema
# O erro `KaggleApiHTTPError: 403 Client Error` indica que você não tem permissão para acessar o modelo Gemma 3N do Kaggle. Isso pode acontecer por dois motivos principais:
#
# 1. **Credenciais não configuradas**: Você não configurou suas credenciais de API do Kaggle
# 2. **Termos não aceitos**: Você não aceitou os termos de uso do modelo Gemma 3N
#
# ## ✅ Solução
#
# ### Passo 1: Configurar Credenciais do Kaggle
# Execute as células abaixo para verificar e configurar suas credenciais.
#
# ### Passo 2: Aceitar Termos do Modelo
# Acesse [https://www.kaggle.com/models/google/gemma-3n](https://www.kaggle.com/models/google/gemma-3n) e clique em **"Accept"** para aceitar os termos de uso.
#
# ### Passo 3: Executar Download
# Após completar os passos acima, execute a célula de download do modelo.
#
# ---

# %%
# !pip install kagglehub
# !pip install kaggle

# %%
# Configurar autenticação do Kaggle usando arquivo existente
import os
import json
import shutil
from pathlib import Path

# Caminhos corrigidos para Windows
current_dir = Path(r'c:\Users\fbg67\Desktop\bufala')  # Diretório atual do projeto
kaggle_json_source = current_dir / 'kaggle.json'
kaggle_dir = Path.home() / '.kaggle'
kaggle_json_dest = kaggle_dir / 'kaggle.json'

print(f"Arquivo de credenciais origem: {kaggle_json_source}")
print(f"Diretório destino: {kaggle_dir}")
print(f"Arquivo destino: {kaggle_json_dest}")

# Verificar se o arquivo de origem existe
if kaggle_json_source.exists():
    print("✓ Arquivo kaggle.json encontrado no diretório do projeto")
    
    # Ler e verificar credenciais
    with open(kaggle_json_source, 'r') as f:
        creds = json.load(f)
        if 'username' in creds and 'key' in creds:
            print(f"✓ Credenciais válidas encontradas para usuário: {creds['username']}")
        else:
            print("✗ Credenciais inválidas no kaggle.json")
            raise ValueError("Credenciais inválidas")
    
    # Criar diretório .kaggle se não existir
    kaggle_dir.mkdir(exist_ok=True)
    print(f"✓ Diretório {kaggle_dir} criado/verificado")
    
    # Copiar arquivo para o local correto
    shutil.copy2(kaggle_json_source, kaggle_json_dest)
    print(f"✓ Arquivo copiado para {kaggle_json_dest}")
    
    # Definir permissões corretas (600)
    os.chmod(kaggle_json_dest, 0o600)
    print("✓ Permissões configuradas para 600")
    
    # Verificar permissões
    import stat
    current_permissions = oct(os.stat(kaggle_json_dest).st_mode)[-3:]
    print(f"✓ Permissões atuais: {current_permissions}")
    
    print("\n🎉 Credenciais do Kaggle configuradas com sucesso!")
    
else:
    print("✗ Arquivo kaggle.json não encontrado no diretório do projeto")
    print(f"✗ Procurado em: {kaggle_json_source}")
    print("\n💡 SOLUÇÕES:")
    print("1. Coloque o arquivo kaggle.json no diretório do projeto")
    print("2. Ou configure manualmente usando a célula abaixo")
    print("3. Ou baixe suas credenciais do Kaggle:")
    print("   - Vá para: https://www.kaggle.com/settings/account")
    print("   - Clique em 'Create New API Token'")
    print("   - Coloque o arquivo baixado no diretório do projeto")

# %%
# Verificar se o arquivo kaggle.json existe no diretório atual
import os
from pathlib import Path

current_dir = Path(r'c:\Users\fbg67\Desktop\bufala')
kaggle_json_path = current_dir / 'kaggle.json'

print(f"🔍 Verificando arquivo kaggle.json em: {kaggle_json_path}")

if kaggle_json_path.exists():
    print("✅ Arquivo kaggle.json encontrado!")
    # Verificar conteúdo
    try:
        with open(kaggle_json_path, 'r') as f:
            import json
            creds = json.load(f)
            if 'username' in creds and 'key' in creds:
                print(f"✅ Credenciais válidas para usuário: {creds['username']}")
            else:
                print("❌ Formato de credenciais inválido")
    except Exception as e:
        print(f"❌ Erro ao ler arquivo: {e}")
else:
    print("❌ Arquivo kaggle.json NÃO encontrado")
    print("\n📋 INSTRUÇÕES para obter o arquivo kaggle.json:")
    print("1. Vá para: https://www.kaggle.com/settings/account")
    print("2. Role para baixo até 'API'")
    print("3. Clique em 'Create New API Token'")
    print("4. Um arquivo kaggle.json será baixado")
    print("5. Mova o arquivo para este diretório:")
    print(f"   {current_dir}")
    print("\n🔄 Após colocar o arquivo, execute esta célula novamente")
# Out:
# 🔍 Verificando arquivo kaggle.json em: c:\Users\fbg67\Desktop\bufala\kaggle.json
# ✅ Arquivo kaggle.json encontrado!
# ✅ Credenciais válidas para usuário: filipebuba

# %%
# OPÇÃO: Criar arquivo kaggle.json manualmente (se você não conseguiu baixar)
import json
from pathlib import Path

def create_kaggle_json_manually():
    """
    Cria o arquivo kaggle.json manualmente com suas credenciais
    """
    print("🔧 CRIANDO ARQUIVO KAGGLE.JSON MANUALMENTE")
    print("=" * 50)
    
    # Solicitar credenciais
    print("Para obter suas credenciais do Kaggle:")
    print("1. Vá para: https://www.kaggle.com/settings/account")
    print("2. Na seção 'API', clique em 'Create New API Token'")
    print("3. Se o download não funcionar, você pode ver as credenciais na página")
    print("\nInsira suas credenciais abaixo:")
    
    username = input("Username do Kaggle: ").strip()
    api_key = input("API Key do Kaggle: ").strip()
    
    if not username or not api_key:
        print("❌ Username e API Key são obrigatórios!")
        return False
    
    # Criar o arquivo
    current_dir = Path(r'c:\Users\fbg67\Desktop\bufala')
    kaggle_json_path = current_dir / 'kaggle.json'
    
    credentials = {
        "username": username,
        "key": api_key
    }
    
    try:
        with open(kaggle_json_path, 'w') as f:
            json.dump(credentials, f, indent=2)
        
        print(f"✅ Arquivo kaggle.json criado em: {kaggle_json_path}")
        print("✅ Agora você pode executar a célula de configuração acima!")
        return True
        
    except Exception as e:
        print(f"❌ Erro ao criar arquivo: {e}")
        return False

# Descomente a linha abaixo para executar a criação manual:
# create_kaggle_json_manually()

# %%
# Configuração automática das credenciais do Kaggle
import os
import json
from pathlib import Path
import getpass

def setup_kaggle_credentials():
    """
    Configura as credenciais do Kaggle interativamente
    """
    kaggle_dir = Path.home() / '.kaggle'
    kaggle_json = kaggle_dir / 'kaggle.json'
    
    if kaggle_json.exists():
        print("✓ Credenciais do Kaggle já existem")
        return True
    
    print("Configurando credenciais do Kaggle...")
    print("\nPara obter suas credenciais:")
    print("1. Vá para: https://www.kaggle.com/settings/account")
    print("2. Clique em 'Create New API Token'")
    print("3. Um arquivo kaggle.json será baixado")
    print("4. Insira as informações abaixo (encontradas no arquivo kaggle.json)")
    
    # Solicitar credenciais
    username = input("\nInsira seu username do Kaggle: ").strip()
    if not username:
        print("Username não pode ser vazio")
        return False
        
    api_key = getpass.getpass("Insira sua API key do Kaggle: ").strip()
    if not api_key:
        print("API key não pode ser vazia")
        return False
    
    # Criar diretório se não existir
    kaggle_dir.mkdir(exist_ok=True)
    
    # Criar arquivo de credenciais
    credentials = {
        "username": username,
        "key": api_key
    }
    
    with open(kaggle_json, 'w') as f:
        json.dump(credentials, f, indent=2)
    
    # Definir permissões corretas
    os.chmod(kaggle_json, 0o600)
    
    print(f"✓ Credenciais salvas em: {kaggle_json}")
    return True

# Comentário: Execute esta célula apenas se você quiser configurar as credenciais interativamente
# setup_kaggle_credentials()

# %%
# Método alternativo: Configurar credenciais via comandos do terminal
print("INSTRUÇÕES PARA CONFIGURAR CREDENCIAIS DO KAGGLE:")
print("=" * 50)
print()
print("Execute os seguintes comandos no terminal:")
print()
print("1. Crie o diretório .kaggle (se não existir):")
print("   mkdir -p ~/.kaggle")
print()
print("2. Baixe suas credenciais do Kaggle:")
print("   - Vá para: https://www.kaggle.com/settings/account")
print("   - Clique em 'Create New API Token'")
print("   - Mova o arquivo baixado: mv ~/Downloads/kaggle.json ~/.kaggle/")
print()
print("3. Configure as permissões:")
print("   chmod 600 ~/.kaggle/kaggle.json")
print()
print("4. OU crie manualmente o arquivo kaggle.json com o conteúdo:")
print("   {")
print('     "username": "SEU_USERNAME",')
print('     "key": "SUA_API_KEY"')
print("   }")
print()
print("5. Após configurar, execute a próxima célula para testar a autenticação")
print()
print("IMPORTANTE: Você também precisa aceitar os termos do modelo Gemma 3N em:")
print("https://www.kaggle.com/models/google/gemma-3n")
# Out:
# INSTRUÇÕES PARA CONFIGURAR CREDENCIAIS DO KAGGLE:
# ==================================================
#
# Execute os seguintes comandos no terminal:
#
# 1. Crie o diretório .kaggle (se não existir):
#    mkdir -p ~/.kaggle
#
# 2. Baixe suas credenciais do Kaggle:
#    - Vá para: https://www.kaggle.com/settings/account
#    - Clique em 'Create New API Token'
#    - Mova o arquivo baixado: mv ~/Downloads/kaggle.json ~/.kaggle/
#
# 3. Configure as permissões:
#    chmod 600 ~/.kaggle/kaggle.json
#
# 4. OU crie manualmente o arquivo kaggle.json com o conteúdo:
#    {
#      "username": "SEU_USERNAME",
#      "key": "SUA_API_KEY"
#    }
#
# 5. Após configurar, execute a próxima célula para testar a autenticação
#
# IMPORTANTE: Você também precisa aceitar os termos do modelo Gemma 3N em:
# https://www.kaggle.com/models/google/gemma-3n

# %%
# Testar autenticação do Kaggle
try:
    import kagglehub
    
    # Tentar listar alguns modelos para testar a autenticação
    print("Testando autenticação do Kaggle...")
    
    # Verificar se conseguimos acessar a API
    from kaggle.api.kaggle_api_extended import KaggleApi
    api = KaggleApi()
    api.authenticate()
    
    print("✓ Autenticação do Kaggle bem-sucedida!")
    
    # Verificar se o modelo Gemma 3N está disponível
    print("\nVerificando disponibilidade do modelo Gemma 3N...")
    
except Exception as e:
    print(f"✗ Erro na autenticação: {e}")
    print("\nPossíveis soluções:")
    print("1. Verifique se suas credenciais do Kaggle estão corretas")
    print("2. Verifique se você aceitou os termos do modelo Gemma 3N no Kaggle")
    print("3. Vá para: https://www.kaggle.com/models/google/gemma-3n")
    print("4. Clique em 'Accept' para aceitar os termos de uso")
# Out:
# Testando autenticação do Kaggle...
# ✓ Autenticação do Kaggle bem-sucedida!
#
# Verificando disponibilidade do modelo Gemma 3N...

# %% [markdown]
# ## 🚨 PASSO IMPORTANTE: Aceitar Termos do Modelo Gemma 3N
#
# ✅ **Suas credenciais do Kaggle estão configuradas e funcionando!**
#
# 🔗 **Agora você DEVE aceitar os termos de uso do modelo:**
#
# 1. Vá para: **https://www.kaggle.com/models/google/gemma-3n**
# 2. Clique no botão **"Accept"** (Aceitar)
# 3. Confirme que aceita os termos de uso
#
# ⚠️ **IMPORTANTE**: O download falhará com erro 403 se você não aceitar os termos primeiro.
#
# 💡 **Dica**: Mantenha a página aberta para verificar se o aceite foi processado.
#
# ---
#
# Após aceitar os termos, execute a célula abaixo para baixar o modelo:

# %%
# %%time
import kagglehub
import os

def download_gemma_model():
    """
    Tenta baixar um modelo Gemma com diferentes abordagens e fallbacks
    """
    
    models_to_try = [
        ("google/gemma-3n/transformers/gemma-3n-e2b-it", "Gemma 3N (2B, Instruction-tuned)"),
        ("google/gemma/transformers/gemma-2b-it", "Gemma 2B (Instruction-tuned)"),
        ("google/gemma/transformers/gemma-7b-it", "Gemma 7B (Instruction-tuned)"),
    ]
    
    for model_handle, model_name in models_to_try:
        try:
            print(f"Tentando baixar {model_name}...")
            GEMMA_PATH = kagglehub.model_download(model_handle)
            print(f"✓ {model_name} baixado com sucesso em: {GEMMA_PATH}")
            return GEMMA_PATH, model_name
        except Exception as e:
            print(f"✗ Erro ao baixar {model_name}: {e}")
            continue
    
    # Se todos os downloads falharam, usar modelo do Hugging Face
    print("\n⚠️  Todos os downloads do Kaggle falharam.")
    print("Usando modelo diretamente do Hugging Face...")
    
    # Modelos alternativos do HF que não requerem autenticação especial
    hf_models = [
        ("google/gemma-2b-it", "Gemma 2B Instruction-tuned"),
        ("microsoft/DialoGPT-medium", "DialoGPT Medium (alternativa)"),
        ("distilgpt2", "DistilGPT-2 (modelo menor)")
    ]
    
    for hf_model, hf_name in hf_models:
        try:
            print(f"Tentando modelo HF: {hf_name}")
            # Testar se o modelo está acessível
            from transformers import AutoTokenizer
            tokenizer_test = AutoTokenizer.from_pretrained(hf_model)
            print(f"✓ {hf_name} acessível no Hugging Face")
            return hf_model, hf_name
        except Exception as e:
            print(f"✗ {hf_name} não acessível: {e}")
            continue
    
    raise Exception("Nenhum modelo pôde ser carregado. Verifique sua conexão e credenciais.")

# Executar download
try:
    GEMMA_PATH, MODEL_NAME = download_gemma_model()
    print(f"\n🎉 Sucesso! Modelo selecionado: {MODEL_NAME}")
    print(f"📁 Caminho/ID: {GEMMA_PATH}")
    
    # Verificar se é um caminho local ou ID do HF
    if os.path.exists(str(GEMMA_PATH)):
        print(f"📍 Tipo: Arquivo local baixado do Kaggle")
    else:
        print(f"🌐 Tipo: Modelo do Hugging Face Hub")
        
except Exception as e:
    print(f"❌ Falha completa: {e}")
    print("\n🔧 Próximos passos:")
    print("1. Configure suas credenciais do Kaggle (células acima)")
    print("2. Aceite os termos do modelo em https://www.kaggle.com/models/google/gemma-3n")
    print("3. Verifique sua conexão com a internet")
# Out:
# Tentando baixar Gemma 3N (2B, Instruction-tuned)...
# Downloading from https://www.kaggle.com/api/v1/models/google/gemma-3n/transformers/gemma-3n-e2b-it/2/download...
# 100%|██████████| 16.0G/16.0G [27:16<00:00, 10.5MB/s]
# Extracting files...

# %%
# %%time
import transformers
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig

def load_model(model_path):
    """
    Carrega o modelo e tokenizer com diferentes configurações
    """
    try:
        print(f"Carregando modelo de: {model_path}")
        
        # Tentar carregar o tokenizer
        tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
        print("✓ Tokenizer carregado com sucesso")
        
        # Verificar se CUDA está disponível
        device = "cuda" if torch.cuda.is_available() else "cpu"
        print(f"Usando dispositivo: {device}")
        
        # Tentar carregar o modelo com diferentes configurações
        if device == "cuda":
            try:
                # Tentar com torch_dtype=torch.bfloat16 para economizar memória
                model = AutoModelForCausalLM.from_pretrained(
                    model_path, 
                    trust_remote_code=True,
                    torch_dtype=torch.bfloat16,
                    device_map="auto"
                )
                print("✓ Modelo carregado com bfloat16 e device_map=auto")
            except Exception as e:
                print(f"Tentativa com bfloat16 falhou: {e}")
                # Fallback para float16
                model = AutoModelForCausalLM.from_pretrained(
                    model_path, 
                    trust_remote_code=True,
                    torch_dtype=torch.float16
                ).to(device)
                print("✓ Modelo carregado com float16")
        else:
            # CPU
            model = AutoModelForCausalLM.from_pretrained(
                model_path, 
                trust_remote_code=True
            )
            print("✓ Modelo carregado na CPU")
        
        return tokenizer, model
        
    except Exception as e:
        print(f"✗ Erro ao carregar modelo: {e}")
        raise

# Carregar modelo e tokenizer
tokenizer, model = load_model(GEMMA_PATH)

# Teste básico
prompt = "What is the capital of Guiné-Bissau?"
print(f"\nTestando com prompt: {prompt}")

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
generation_config = GenerationConfig(max_new_tokens=150, do_sample=True, temperature=0.7)

with torch.no_grad():
    outputs = model.generate(**inputs, generation_config=generation_config)
    result = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("✓ Teste de geração concluído")
# Out:
# Carregando modelo de: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it\1
# ✓ Tokenizer carregado com sucesso
# Usando dispositivo: cpu
# ✓ Tokenizer carregado com sucesso
# Usando dispositivo: cpu
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ✓ Modelo carregado na CPU
#
# Testando com prompt: What is the capital of France?
# `generation_config` default values have been modified to match model-specific defaults: {'cache_implementation': 'hybrid', 'top_k': 64, 'top_p': 0.95, 'pad_token_id': 0, 'bos_token_id': 2, 'eos_token_id': [1, 106]}. If this is not desired, please set these values explicitly.
# ✓ Teste de geração concluído
# CPU times: total: 1min 42s
# Wall time: 1min 7s

# %%
print(result)
# Out:
# What is the capital of France?
#
# Paris

# %%
# %%time
def gemma_query(input_text):
    """
    Função para fazer queries ao modelo Gemma
    """
    try:
        # Verificar se o input não está vazio
        if not input_text.strip():
            return "Por favor, digite uma pergunta."
        
        # Preparar input
        inputs = tokenizer(input_text, return_tensors="pt").to(model.device)
        
        # Gerar resposta
        with torch.no_grad():
            outputs = model.generate(
                **inputs, 
                max_new_tokens=100,
                do_sample=True,
                temperature=0.7,
                top_p=0.9,
                pad_token_id=tokenizer.eos_token_id
            )
        
        # Decodificar resposta
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        
        # Remover o prompt original da resposta
        if input_text in response:
            response = response.replace(input_text, "").strip()
        
        return response
        
    except Exception as e:
        return f"Erro ao processar query: {str(e)}"

# Testar a função
test_query = "Explain photosynthesis in simple terms."
test_result = gemma_query(test_query)
print(f"Teste da função gemma_query:")
print(f"Input: {test_query}")
print(f"Output: {test_result}")
# Out:
# Teste da função gemma_query:
# Input: Explain photosynthesis in simple terms.
# Output: Imagine plants are like tiny food factories!
#
# They take in:
#
# * **Sunlight:** Like the power source for the factory.
# * **Water:**  Like an ingredient.
# * **Carbon Dioxide (from the air):**  Another ingredient.
#
# Inside their leaves, plants have special green stuff called **chlorophyll**. Chlorophyll captures the sunlight.
#
# Then, using the sunlight's energy, the plant turns the water and carbon dioxide into:
#
# * **Sugar
# CPU times: total: 5min 31s
# Wall time: 55.9 s

# %%
# %%time
import gradio as gr

# Define the interface
demo = gr.Interface(
    fn=gemma_query,
    inputs=gr.Textbox(label="Enter your query"),
    outputs=gr.Textbox(label="Gemma 3n Response"),
    title="Gemma 3n: [Your Project Name]",
    description="Powered by Gemma 3n – A private, offline-first, multimodal AI model.",
    examples=[["Tell me about climate change."], ["Explain photosynthesis in simple terms."]],
    theme="default"
)

# Launch the interface
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# CPU times: total: 4.23 s
# Wall time: 6.18 s

# %%
# 🔍 VERIFICAR SE O MODELO GEMMA-3N JÁ FOI BAIXADO
import os
from pathlib import Path
import json

def check_existing_gemma_models():
    """
    Verifica se já existe algum modelo Gemma baixado no sistema
    """
    print("🔍 VERIFICANDO MODELOS GEMMA JÁ BAIXADOS")
    print("=" * 50)
    
    # Locais comuns onde modelos podem estar armazenados
    possible_locations = [
        # Cache do Kaggle
        Path.home() / ".cache" / "kagglehub",
        
        # Cache do Hugging Face
        Path.home() / ".cache" / "huggingface",
        
        # Diretório atual do projeto
        Path(r'c:\Users\fbg67\Desktop\bufala') / "models",
        
        # Outros locais comuns
        Path(r'c:\Users\fbg67\.cache\kagglehub'),
        Path(r'c:\Users\fbg67\.cache\huggingface'),
        
        # Verificar se há variáveis de ambiente
        Path(os.environ.get('TRANSFORMERS_CACHE', '')),
        Path(os.environ.get('KAGGLE_CACHE_DIR', '')),
    ]
    
    found_models = []
    
    for location in possible_locations:
        if location and location.exists():
            print(f"\n📁 Verificando: {location}")
            
            try:
                # Procurar por modelos Gemma
                for root, dirs, files in os.walk(location):
                    root_path = Path(root)
                    
                    # Verificar se contém "gemma" no nome do diretório
                    if any("gemma" in part.lower() for part in root_path.parts):
                        print(f"  🎯 Encontrado: {root_path}")
                        
                        # Verificar conteúdo
                        model_files = list(root_path.glob("*.bin")) + list(root_path.glob("*.safetensors")) + list(root_path.glob("config.json"))
                        if model_files:
                            found_models.append({
                                'path': root_path,
                                'files': [f.name for f in model_files[:5]],  # Primeiros 5 arquivos
                                'total_files': len(list(root_path.iterdir()))
                            })
                            print(f"    📄 Arquivos encontrados: {len(list(root_path.iterdir()))} arquivos")
                            print(f"    📋 Exemplos: {', '.join([f.name for f in model_files[:3]])}")
                        
            except (PermissionError, OSError) as e:
                print(f"  ⚠️ Sem permissão para acessar: {e}")
        else:
            if location:
                print(f"❌ Não existe: {location}")
    
    return found_models

def check_specific_gemma_paths():
    """
    Verifica caminhos específicos conhecidos do Gemma
    """
    print("\n🎯 VERIFICANDO CAMINHOS ESPECÍFICOS DO GEMMA")
    print("=" * 50)
    
    # Caminhos específicos baseados nos downloads anteriores
    specific_paths = [
        # Do log do backend que vimos antes
        Path(r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1"),
        
        # Possíveis caminhos do transformers
        Path(r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers"),
        Path(r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma"),
        
        # Cache do Hugging Face
        Path.home() / ".cache" / "huggingface" / "hub" / "models--google--gemma-2b-it",
        Path.home() / ".cache" / "huggingface" / "hub" / "models--google--gemma-3n-e2b-it",
    ]
    
    found_specific = []
    
    for path in specific_paths:
        if path.exists():
            print(f"✅ ENCONTRADO: {path}")
            
            # Listar conteúdo
            contents = list(path.iterdir())
            print(f"   📂 Conteúdo ({len(contents)} itens):")
            for item in contents[:10]:  # Primeiros 10 itens
                print(f"     📄 {item.name}")
            
            if len(contents) > 10:
                print(f"     ... e mais {len(contents) - 10} itens")
                
            found_specific.append(path)
        else:
            print(f"❌ Não encontrado: {path}")
    
    return found_specific

# Executar verificações
print("🚀 INICIANDO VERIFICAÇÃO DE MODELOS GEMMA...")
found_models = check_existing_gemma_models()
found_specific = check_specific_gemma_paths()

print(f"\n📊 RESUMO:")
print(f"📦 Modelos encontrados (busca geral): {len(found_models)}")
print(f"🎯 Caminhos específicos encontrados: {len(found_specific)}")

if found_models or found_specific:
    print(f"\n✅ MODELOS GEMMA ENCONTRADOS NO SISTEMA!")
    print("💡 Você pode usar um destes modelos em vez de baixar novamente.")
    
    # Mostrar o melhor candidato
    if found_specific:
        best_path = found_specific[0]
        print(f"\n🎯 MELHOR CANDIDATO: {best_path}")
        print("💡 Você pode usar este caminho para carregar o modelo diretamente!")
    elif found_models:
        best_model = found_models[0]
        print(f"\n🎯 MELHOR CANDIDATO: {best_model['path']}")
        print("💡 Você pode usar este caminho para carregar o modelo diretamente!")
else:
    print(f"\n❌ NENHUM MODELO GEMMA ENCONTRADO")
    print("📥 Será necessário baixar o modelo usando as células acima.")
# Out:
# 🚀 INICIANDO VERIFICAÇÃO DE MODELOS GEMMA...
# 🔍 VERIFICANDO MODELOS GEMMA JÁ BAIXADOS
# ==================================================
#
# 📁 Verificando: C:\Users\fbg67\.cache\kagglehub
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it
#   🎯 Encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it\1
#     📄 Arquivos encontrados: 14 arquivos
#     📋 Exemplos: model-00001-of-00003.safetensors, model-00002-of-00003.safetensors, model-00003-of-00003.safetensors
#
# 📁 Verificando: C:\Users\fbg67\.cache\huggingface
#
# 📁 Verificando: c:\Users\fbg67\Desktop\bufala\models
#
# 📁 Verificando: c:\Users\fbg67\.cache\kagglehub
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it
#   🎯 Encontrado: c:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it\1
#     📄 Arquivos encontrados: 14 arquivos
#     📋 Exemplos: model-00001-of-00003.safetensors, model-00002-of-00003.safetensors, model-00003-of-00003.safetensors
#
# 📁 Verificando: c:\Users\fbg67\.cache\huggingface
#
# 📁 Verificando: .
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma2
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma2\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma3
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma3\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma3n
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\gemma3n\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\paligemma
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\paligemma\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\recurrent_gemma
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\recurrent_gemma\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\shieldgemma2
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\shieldgemma2\__pycache__
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\t5gemma
#   🎯 Encontrado: .venv\Lib\site-packages\transformers\models\t5gemma\__pycache__
#   🎯 Encontrado: google-gemma-3n-hackathon
#   🎯 Encontrado: google-gemma-3n-hackathon\archive
#   🎯 Encontrado: venv_gemma
#   🎯 Encontrado: venv_gemma\etc
#   🎯 Encontrado: venv_gemma\etc\jupyter
#   🎯 Encontrado: venv_gemma\etc\jupyter\jupyter_notebook_config.d
#   🎯 Encontrado: venv_gemma\etc\jupyter\jupyter_server_config.d
#   🎯 Encontrado: venv_gemma\etc\jupyter\nbconfig
#   🎯 Encontrado: venv_gemma\etc\jupyter\nbconfig\notebook.d
#   🎯 Encontrado: venv_gemma\Include
#   🎯 Encontrado: venv_gemma\Lib
#   🎯 Encontrado: venv_gemma\Lib\site-packages
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\flags
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\flags\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\logging
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\logging\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\testing
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\testing\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl_py-2.3.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\absl_py-2.3.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands\config
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands\config\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands\menu
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands\menu\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\commands\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils\scripts
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils\scripts\external_deps
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils\scripts\external_deps\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils\scripts\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\test_utils\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\utils\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate-1.8.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\accelerate-1.8.1.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi\examples
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi\examples\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\adodbapi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles\tempfile
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles\tempfile\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles\threadpool
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles\threadpool\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles-24.1.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\aiofiles-24.1.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\annotated_types
#   🎯 Encontrado: venv_gemma\Lib\site-packages\annotated_types\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\annotated_types-0.7.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\annotated_types-0.7.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\abc
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\abc\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\streams
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\streams\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\_backends
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\_backends\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\_core
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\_core\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\anyio-4.9.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\argon2
#   🎯 Encontrado: venv_gemma\Lib\site-packages\argon2\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\argon2_cffi-25.1.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\argon2_cffi-25.1.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\argon2_cffi_bindings-21.2.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\arrow
#   🎯 Encontrado: venv_gemma\Lib\site-packages\arrow\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\arrow-1.3.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\asttokens
#   🎯 Encontrado: venv_gemma\Lib\site-packages\asttokens\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\asttokens-3.0.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\astunparse
#   🎯 Encontrado: venv_gemma\Lib\site-packages\astunparse\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\astunparse-1.6.3.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\async_lru
#   🎯 Encontrado: venv_gemma\Lib\site-packages\async_lru\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\async_lru-2.0.5.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attr
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attr\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attrs
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attrs\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attrs-25.3.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\attrs-25.3.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\locale-data
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\localtime
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\localtime\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\messages
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\messages\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\babel-2.17.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\beautifulsoup4-4.13.4.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\beautifulsoup4-4.13.4.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\filters
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\filters\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treeadapters
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treeadapters\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treebuilders
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treebuilders\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treewalkers
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\treewalkers\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\_trie
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\_trie\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\html5lib-1.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\_vendor\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bleach-6.2.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\blinker
#   🎯 Encontrado: venv_gemma\Lib\site-packages\blinker\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\blinker-1.9.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\builder
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\builder\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\tests\fuzz
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\bs4\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\certifi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\certifi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\certifi-2025.6.15.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\certifi-2025.6.15.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\cffi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\cffi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\cffi-1.17.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer\cli
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer\cli\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer-3.4.2.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\charset_normalizer-3.4.2.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\clang
#   🎯 Encontrado: venv_gemma\Lib\site-packages\clang\native
#   🎯 Encontrado: venv_gemma\Lib\site-packages\clang\native\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\clang\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\click
#   🎯 Encontrado: venv_gemma\Lib\site-packages\click\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\click-8.2.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\click-8.2.1.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama-0.4.6.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\colorama-0.4.6.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\comm
#   🎯 Encontrado: venv_gemma\Lib\site-packages\comm\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\comm-0.2.2.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\comm-0.2.2.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\DateTime
#   🎯 Encontrado: venv_gemma\Lib\site-packages\DateTime\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\DateTime\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\DateTime\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\DateTime-5.5.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\parser
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\parser\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\tz
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\tz\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\zoneinfo
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\zoneinfo\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil-stubs
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil-stubs\parser
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil-stubs\tz
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dateutil-stubs\zoneinfo
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\adapter
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\adapter\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\common
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\common\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\launcher
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\launcher\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\server
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\server\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\common
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\linux_and_mac
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\linux_and_mac\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg\win32
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg\win32\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\windows
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\types
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\types\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydev_ipython
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydev_ipython\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydev_sitecustomize
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\pydev_sitecustomize\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_concurrency_analyser
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_concurrency_analyser\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\_debug_adapter
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\_debug_adapter\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored\bytecode
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored\bytecode\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored\bytecode\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored\bytecode\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\vendored\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_frame_eval\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_sys_monitoring
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_sys_monitoring\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\fsnotify
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\fsnotify\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_runfiles
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\_pydev_runfiles\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\pydevd\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\_vendored\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy-1.8.14.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\debugpy-1.8.14.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\decorator-5.2.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\defusedxml
#   🎯 Encontrado: venv_gemma\Lib\site-packages\defusedxml\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\defusedxml-0.7.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dotenv
#   🎯 Encontrado: venv_gemma\Lib\site-packages\dotenv\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\executing
#   🎯 Encontrado: venv_gemma\Lib\site-packages\executing\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\executing-2.2.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\dependencies
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\dependencies\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\middleware
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\middleware\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\openapi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\openapi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\security
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\security\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi-0.115.14.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastapi-0.115.14.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastjsonschema
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastjsonschema\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fastjsonschema-2.21.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\ffmpy
#   🎯 Encontrado: venv_gemma\Lib\site-packages\ffmpy\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\ffmpy-0.6.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\filelock
#   🎯 Encontrado: venv_gemma\Lib\site-packages\filelock\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\filelock-3.18.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\filelock-3.18.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask\json
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask\json\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask-2.3.3.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask_cors
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flask_cors\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\Flask_Cors-4.0.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flatbuffers
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flatbuffers\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\flatbuffers-25.2.10.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fqdn
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fqdn\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fqdn-1.5.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\implementations
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\implementations\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\tests\abstract
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\tests\abstract\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec-2025.5.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\fsspec-2025.5.1.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\compile
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\compile\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\dim
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\dim\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\einops
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\einops\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\experimental
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\experimental\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\aot_autograd
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\aot_autograd\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\eager_transforms
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\eager_transforms\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\make_functional
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\make_functional\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\vmap
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\vmap\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\_src\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\functorch\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gast
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gast\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gast-0.6.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\compiler
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\compiler\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\internal
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\internal\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\pyext
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\pyext\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\testdata
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\testdata\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\util
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\util\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\protobuf\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google\_upb
#   🎯 Encontrado: venv_gemma\Lib\site-packages\google_pasta-0.2.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\commands
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\commands\components
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\commands\components\files
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\commands\components\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\commands\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\cli\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\components
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\components\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\icons
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\layouts
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\layouts\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\sketch
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\sketch\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\stubs
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\assets
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\assets\svelte
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\IBMPlexMono
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\IBMPlexSans
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\Inconsolata
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\Montserrat
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\Quicksand
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\fonts\Source Sans Pro
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\frontend\static\img
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable\assets
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable\chunks
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable\entry
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable\nodes
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\client\_app\immutable\workers
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\server
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\templates\node\build\server\chunks
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\test_data
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\test_data\flagged_no_log
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\test_data\flagged_with_log
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\test_data\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\themes
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\themes\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\themes\utils\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\themes\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\accordion
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\accordion\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\annotatedimage
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\atoms
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\atoms\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\atoms\src\icons
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\atoms\src\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\interactive
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\player
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\recorder
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\static
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\audio\streaming
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\box
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\browserstate
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\build
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\build\out
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\build\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\button
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\button\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\chatbot
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\chatbot\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\checkbox
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\checkbox\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\checkboxgroup
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\client
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\client\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\client\src\helpers
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\client\src\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\code
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\code\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\colorpicker
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\colorpicker\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\column
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataframe
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataframe\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataframe\shared\context
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataframe\shared\icons
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataframe\shared\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dataset
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\datetime
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\downloadbutton
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\downloadbutton\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dropdown
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\dropdown\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\fallback
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\file
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\file\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\fileexplorer
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\fileexplorer\icons
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\fileexplorer\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\form
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\gallery
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\gallery\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\group
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\highlightedtext
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\highlightedtext\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\html
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\html\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\icons
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\icons\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\image
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\image\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\brush
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\core
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\crop
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\image
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\resize
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageeditor\shared\zoom
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageslider
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\imageslider\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\json
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\json\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\label
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\label\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\examples
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\examples\transformers_basic
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\src\custom-element
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\src\dev
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\lite\src\images
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\markdown
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\markdown\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\markdown-code
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\model3D
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\model3D\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\multimodaltextbox
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\multimodaltextbox\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\nativeplot
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\number
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\paramviewer
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\plot
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\plot\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\plot\shared\plot_types
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\src\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\backend
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\backend\gradio_test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\backend\gradio_test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\demo
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\demo\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\preview\test\test\frontend
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\radio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\radio\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\row
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\sanitize
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\sidebar
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\sidebar\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\simpledropdown
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\simpleimage
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\simpleimage\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\simpletextbox
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\sketchbox
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\slider
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\state
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\statustracker
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\statustracker\static
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tabitem
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tabitem\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tabs
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tabs\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\textbox
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\textbox\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\theme
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\theme\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\timer
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tooltip
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tooltip\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tootils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\tootils\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\upload
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\upload\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\uploadbutton
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\uploadbutton\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\utils\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\video
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\video\shared
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\network
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src\webworker
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src\webworker\code-completion
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src\webworker\code-completion\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src\webworker\py
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\src\webworker\py\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_frontend_code\wasm\svelte
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_simple_templates
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\_simple_templates\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio-5.35.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio-5.35.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client\cli
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client\cli\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client\templates
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client\templates\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\gradio_client-1.10.4.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\groovy
#   🎯 Encontrado: venv_gemma\Lib\site-packages\groovy\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\groovy-0.1.2.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\groovy-0.1.2.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\aio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\aio\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\beta
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\beta\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\experimental
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\experimental\aio
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\experimental\aio\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\experimental\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\common
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\common\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\foundation
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\foundation\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces\base
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces\base\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces\face
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces\face\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\interfaces\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\framework\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\_cython
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\_cython\_credentials
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\_cython\_cygrpc
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\_cython\_cygrpc\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\_cython\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpc\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\grpcio-1.73.1.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h11
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h11\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h11-0.16.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h11-0.16.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests\data_files
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests\data_files\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests\test_vds
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests\test_vds\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\_hl
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\_hl\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py-3.14.0.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py-3.14.0.dist-info\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py-3.14.0.dist-info\licenses\licenses
#   🎯 Encontrado: venv_gemma\Lib\site-packages\h5py-3.14.0.dist-info\licenses\lzf
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_async
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_async\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_backends
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_backends\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_sync
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\_sync\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\httpcore\__pycache__
# ...
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axdebug\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\client
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\client\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos\client
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos\client\asp
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos\client\asp\interrupt
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos\client\ie
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\Demos\client\wsh
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\server
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\server\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\axscript\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\bits
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\bits\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\bits\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\bits\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\directsound
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\directsound\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\directsound\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\directsound\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\ifilter
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\ifilter\demo
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\ifilter\demo\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\ifilter\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\internet
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\internet\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\mapi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\mapi\demos
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\mapi\demos\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\mapi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\propsys
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\propsys\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\propsys\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\propsys\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\demos
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\demos\servers
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\demos\servers\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\demos\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\shell\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\taskscheduler
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\taskscheduler\test
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\taskscheduler\test\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\win32comext\taskscheduler\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\winpty
#   🎯 Encontrado: venv_gemma\Lib\site-packages\winpty\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\winpty\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\winpty\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\wrapt
#   🎯 Encontrado: venv_gemma\Lib\site-packages\wrapt\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\wrapt-1.17.2.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\yaml
#   🎯 Encontrado: venv_gemma\Lib\site-packages\yaml\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\auth
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\auth\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend\cffi
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend\cffi\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend\cython
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend\cython\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\backend\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\devices
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\devices\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\eventloop
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\eventloop\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\green
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\green\eventloop
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\green\eventloop\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\green\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\log
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\log\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\ssh
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\ssh\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\sugar
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\sugar\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\utils
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\utils\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zmq\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\common
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\common\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\common\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\common\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\tests
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\tests\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope\interface\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\zope.interface-7.2.dist-info
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_argon2_cffi_bindings
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_argon2_cffi_bindings\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_distutils_hack
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_distutils_hack\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_yaml
#   🎯 Encontrado: venv_gemma\Lib\site-packages\_yaml\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\__pycache__
#   🎯 Encontrado: venv_gemma\Lib\site-packages\~umpy
#   🎯 Encontrado: venv_gemma\Lib\site-packages\~umpy\linalg
#   🎯 Encontrado: venv_gemma\Lib\site-packages\~umpy\random
#   🎯 Encontrado: venv_gemma\Lib\site-packages\~umpy\_core
#   🎯 Encontrado: venv_gemma\Lib\site-packages\~umpy.libs
#   🎯 Encontrado: venv_gemma\Scripts
#   🎯 Encontrado: venv_gemma\Scripts\__pycache__
#   🎯 Encontrado: venv_gemma\share
#   🎯 Encontrado: venv_gemma\share\applications
#   🎯 Encontrado: venv_gemma\share\icons
#   🎯 Encontrado: venv_gemma\share\icons\hicolor
#   🎯 Encontrado: venv_gemma\share\icons\hicolor\scalable
#   🎯 Encontrado: venv_gemma\share\icons\hicolor\scalable\apps
#   🎯 Encontrado: venv_gemma\share\jupyter
#   🎯 Encontrado: venv_gemma\share\jupyter\kernels
#   🎯 Encontrado: venv_gemma\share\jupyter\kernels\python3
#   🎯 Encontrado: venv_gemma\share\jupyter\lab
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook\application-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook\documentsearch-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook\help-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook\notebook-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyter-notebook\tree-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\application-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\apputils-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\cell-toolbar-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\celltags-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\codemirror-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\completer-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\console-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\csvviewer-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\debugger-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\docmanager-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\documentsearch-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\extensionmanager-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\filebrowser-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\fileeditor-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\help-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\htmlviewer-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\hub-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\imageviewer-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\inspector-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\launcher-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\logconsole-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\lsp-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\mainmenu-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\markdownviewer-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\mathjax-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\metadataform-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\notebook-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\running-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\settingeditor-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\shortcuts-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\statusbar-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\terminal-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\toc-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\tooltip-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\translation-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\schemas\@jupyterlab\workspaces-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\static
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\themes
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\themes\@jupyterlab
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\themes\@jupyterlab\theme-dark-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\themes\@jupyterlab\theme-dark-high-contrast-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\lab\themes\@jupyterlab\theme-light-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook\lab-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook\lab-extension\schemas
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook\lab-extension\schemas\@jupyter-notebook
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook\lab-extension\schemas\@jupyter-notebook\lab-extension
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-notebook\lab-extension\static
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\schemas
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\schemas\@jupyter-widgets
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\schemas\@jupyter-widgets\jupyterlab-manager
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\jupyterlab_pygments
#   🎯 Encontrado: venv_gemma\share\jupyter\labextensions\jupyterlab_pygments\static
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\asciidoc
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\base
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\basic
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\classic
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\classic\static
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\compatibility
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\lab
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\lab\static
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\latex
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\markdown
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\python
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\reveal
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\reveal\static
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\rst
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\script
#   🎯 Encontrado: venv_gemma\share\jupyter\nbconvert\templates\webpdf
#   🎯 Encontrado: venv_gemma\share\jupyter\nbextensions
#   🎯 Encontrado: venv_gemma\share\jupyter\nbextensions\jupyter-js-widgets
#   🎯 Encontrado: venv_gemma\share\man
#   🎯 Encontrado: venv_gemma\share\man\man1
#
# 🎯 VERIFICANDO CAMINHOS ESPECÍFICOS DO GEMMA
# ==================================================
# ✅ ENCONTRADO: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1
#    📂 Conteúdo (1 itens):
#      📄 gemma-3n-E2B-it-int4.task
# ✅ ENCONTRADO: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers
#    📂 Conteúdo (1 itens):
#      📄 gemma-3n-e2b-it
# ❌ Não encontrado: C:\Users\fbg67\.cache\kagglehub\models\google\gemma
# ❌ Não encontrado: C:\Users\fbg67\.cache\huggingface\hub\models--google--gemma-2b-it
# ❌ Não encontrado: C:\Users\fbg67\.cache\huggingface\hub\models--google--gemma-3n-e2b-it
#
# 📊 RESUMO:
# 📦 Modelos encontrados (busca geral): 6
# 🎯 Caminhos específicos encontrados: 2
#
# ✅ MODELOS GEMMA ENCONTRADOS NO SISTEMA!
# 💡 Você pode usar um destes modelos em vez de baixar novamente.
#
# 🎯 MELHOR CANDIDATO: C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1
# 💡 Você pode usar este caminho para carregar o modelo diretamente!

# %%
# 🚀 TENTAR CARREGAR MODELO GEMMA EXISTENTE
from pathlib import Path
import os

def try_load_existing_gemma():
    """
    Tenta carregar um modelo Gemma já existente no sistema
    """
    print("🚀 TENTANDO CARREGAR MODELO GEMMA EXISTENTE")
    print("=" * 50)
    
    # Caminhos conhecidos onde o modelo pode estar (baseado nos logs anteriores)
    known_paths = [
        # Do log do backend - sabemos que este existe
        r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\TfLite\gemma-3n-e2b-it-int4\1",
        
        # Possíveis locais de transformers
        r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma-3n\transformers\gemma-3n-e2b-it",
        r"C:\Users\fbg67\.cache\kagglehub\models\google\gemma\transformers\gemma-2b-it",
        
        # Diretório do usuário
        os.path.expanduser("~/.cache/kagglehub/models/google/gemma-3n"),
        os.path.expanduser("~/.cache/huggingface/hub/models--google--gemma-2b-it"),
    ]
    
    # Tentar cada caminho
    for path_str in known_paths:
        path = Path(path_str)
        if path.exists():
            print(f"✅ Encontrado: {path}")
            
            # Verificar se é um modelo TfLite ou Transformers
            files = list(path.rglob("*"))
            
            # Procurar por arquivos específicos
            has_task_file = any(".task" in f.name for f in files)
            has_config_json = any("config.json" in f.name for f in files)
            has_model_files = any(f.suffix in ['.bin', '.safetensors'] for f in files)
            
            print(f"   📄 Arquivos .task: {'✅' if has_task_file else '❌'}")
            print(f"   📄 config.json: {'✅' if has_config_json else '❌'}")  
            print(f"   📄 Arquivos de modelo: {'✅' if has_model_files else '❌'}")
            
            if has_task_file:
                print(f"   🎯 MODELO TfLite/MediaPipe detectado!")
                return path, "tflite"
            elif has_config_json and has_model_files:
                print(f"   🎯 MODELO TRANSFORMERS detectado!")
                return path, "transformers"
            else:
                print(f"   ⚠️ Tipo de modelo não identificado")
        else:
            print(f"❌ Não existe: {path}")
    
    print("\n❌ Nenhum modelo compatível encontrado")
    return None, None

def load_found_model(model_path, model_type):
    """
    Carrega o modelo encontrado
    """
    if model_type == "transformers":
        try:
            from transformers import AutoTokenizer, AutoModelForCausalLM
            print(f"🔧 Carregando modelo Transformers de: {model_path}")
            
            tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
            model = AutoModelForCausalLM.from_pretrained(model_path, trust_remote_code=True)
            
            print("✅ Modelo Transformers carregado com sucesso!")
            return tokenizer, model, str(model_path)
            
        except Exception as e:
            print(f"❌ Erro ao carregar modelo Transformers: {e}")
            return None, None, None
    
    elif model_type == "tflite":
        print(f"🔧 Modelo TfLite encontrado em: {model_path}")
        print("⚠️ Modelos TfLite requerem configuração especial")
        print("💡 Recomendação: Use a função de download para obter versão Transformers")
        return None, None, str(model_path)
    
    return None, None, None

# Executar busca e tentativa de carregamento
print("🔍 Procurando modelos Gemma existentes...")
model_path, model_type = try_load_existing_gemma()

if model_path and model_type:
    print(f"\n🎉 MODELO ENCONTRADO!")
    print(f"📁 Caminho: {model_path}")
    print(f"🏷️ Tipo: {model_type}")
    
    if model_type == "transformers":
        print("\n🚀 Tentando carregar modelo...")
        tokenizer, model, GEMMA_PATH = load_found_model(model_path, model_type)
        
        if tokenizer and model:
            print("✅ MODELO CARREGADO COM SUCESSO!")
            print("🎯 Você pode pular a célula de download e ir direto para os testes!")
            
            # Definir variáveis globais para uso nas próximas células
            MODEL_NAME = f"Gemma (carregado de {model_path.name})"
        else:
            print("❌ Falha ao carregar. Use a célula de download.")
    else:
        print("💡 Modelo TfLite encontrado, mas recomendamos baixar versão Transformers")
        print("🔄 Execute as células de download para obter versão compatível")
else:
    print("\n📥 Nenhum modelo encontrado. Execute as células de download.")

# %%
# 🚀 ANÁLISE DE PERFORMANCE - Por que o Gemma-3n está lento no backend?

def analyze_performance_issues():
    """
    Analisa e corrige problemas de performance do Gemma-3n
    """
    print("🔍 ANÁLISE DE PERFORMANCE DO GEMMA-3N")
    print("=" * 55)
    
    print("\n🐌 PROBLEMAS IDENTIFICADOS NO BACKEND ATUAL:")
    print("1. ❌ Max_length muito alto (512) - causando demora")
    print("2. ❌ Temperature alta (0.7) - mais diversidade = mais tempo")
    print("3. ❌ Top_p alto (0.9) - muitas opções de tokens")
    print("4. ❌ Do_sample=True - sampling é mais lento que greedy")
    print("5. ❌ Prompt muito longo com contexto desnecessário")
    print("6. ❌ Dispositivo pode estar em CPU em vez de GPU")
    
    print("\n⚡ OTIMIZAÇÕES DO NOTEBOOK (RÁPIDAS):")
    print("1. ✅ Max_new_tokens=100-150 (mais rápido)")
    print("2. ✅ Temperature=0.3-0.5 (menos diversidade, mais velocidade)")
    print("3. ✅ Top_p=0.8 (menos opções = mais rápido)")
    print("4. ✅ Prompt conciso e direto")
    print("5. ✅ Verificação adequada de dispositivo")
    print("6. ✅ Torch.no_grad() para economia de memória")
    
    print("\n🎯 CONFIGURAÇÃO OTIMIZADA RECOMENDADA:")
    optimized_config = {
        "max_new_tokens": 100,        # Em vez de max_length=512
        "temperature": 0.3,           # Em vez de 0.7
        "top_p": 0.8,                # Em vez de 0.9
        "do_sample": True,           # Mantido, mas com menos randomness
        "num_beams": 1,              # Sem beam search para velocidade
        "early_stopping": True,       # Para parar cedo quando apropriado
        "pad_token_id": "auto",      # Evitar warnings
        "eos_token_id": "auto"       # Parada adequada
    }
    
    for key, value in optimized_config.items():
        print(f"   {key}: {value}")
    
    return optimized_config

def demonstrate_fast_generation():
    """
    Demonstra geração rápida vs lenta para comparação
    """
    print("\n🏃‍♂️ DEMONSTRAÇÃO: CONFIGURAÇÃO RÁPIDA VS LENTA")
    print("=" * 55)
    
    # Configurações para comparar
    configs = {
        "🐌 LENTA (atual backend)": {
            "max_new_tokens": 512,
            "temperature": 0.7,
            "top_p": 0.9,
            "do_sample": True
        },
        "⚡ RÁPIDA (otimizada)": {
            "max_new_tokens": 50,
            "temperature": 0.3,
            "top_p": 0.8,
            "do_sample": True
        },
        "🚀 ULTRA RÁPIDA (greedy)": {
            "max_new_tokens": 30,
            "temperature": 0.1,
            "do_sample": False  # Greedy decoding
        }
    }
    
    for config_name, config in configs.items():
        print(f"\n{config_name}:")
        for param, value in config.items():
            print(f"   {param}: {value}")
    
    print("\n💡 RECOMENDAÇÃO PARA BACKEND BU FALA:")
    print("   Use configuração RÁPIDA para respostas médicas")
    print("   Use ULTRA RÁPIDA para emergências")
    print("   Reserve LENTA apenas para conteúdo educativo extenso")

def create_optimized_backend_config():
    """
    Cria arquivo de configuração otimizado para o backend
    """
    print("\n🔧 CRIANDO CONFIGURAÇÃO OTIMIZADA PARA BACKEND")
    print("=" * 55)
    
    optimized_backend_config = {
        "model_name": "google/gemma-3-2b-it",
        "display_name": "Bu Fala Gemma-3n (Otimizado)",
        "max_new_tokens": 100,     # ⚡ Reduzido de 512
        "temperature": 0.3,        # ⚡ Reduzido de 0.7  
        "top_p": 0.8,             # ⚡ Reduzido de 0.9
        "do_sample": True,
        "num_beams": 1,           # ⚡ Sem beam search
        "early_stopping": True,    # ⚡ Parada antecipada
        "offline_mode": True,
        "local_model_path": None,
        "torch_dtype": "float16",  # ⚡ Economia de memória
        "device_map": "auto"       # ⚡ GPU automática
    }
    
    # Salvar no diretório do projeto
    import json
    from pathlib import Path
    
    config_file = Path(r'c:\Users\fbg67\Desktop\bufala\gemma3_config_optimized.json')
    
    with open(config_file, 'w') as f:
        json.dump(optimized_backend_config, f, indent=4)
    
    print(f"✅ Configuração otimizada salva em: {config_file}")
    print("\n📋 PARA APLICAR A OTIMIZAÇÃO:")
    print("1. Pare o backend atual")
    print("2. Renomeie gemma3_config.json para gemma3_config_backup.json") 
    print("3. Renomeie gemma3_config_optimized.json para gemma3_config.json")
    print("4. Reinicie o backend")
    print("5. Teste uma consulta médica - deve ser 5-10x mais rápida!")
    
    return optimized_backend_config

# Executar análise
print("🚀 INICIANDO ANÁLISE DE PERFORMANCE...")
optimized_config = analyze_performance_issues()
demonstrate_fast_generation()
backend_config = create_optimized_backend_config()

print(f"\n🎉 ANÁLISE COMPLETA!")
print("💡 Com essas otimizações, o Gemma-3n deve responder em 10-30 segundos")
print("   em vez de 2-3 minutos como está acontecendo atualmente.")
# Out:
# 🚀 INICIANDO ANÁLISE DE PERFORMANCE...
# 🔍 ANÁLISE DE PERFORMANCE DO GEMMA-3N
# =======================================================
#
# 🐌 PROBLEMAS IDENTIFICADOS NO BACKEND ATUAL:
# 1. ❌ Max_length muito alto (512) - causando demora
# 2. ❌ Temperature alta (0.7) - mais diversidade = mais tempo
# 3. ❌ Top_p alto (0.9) - muitas opções de tokens
# 4. ❌ Do_sample=True - sampling é mais lento que greedy
# 5. ❌ Prompt muito longo com contexto desnecessário
# 6. ❌ Dispositivo pode estar em CPU em vez de GPU
#
# ⚡ OTIMIZAÇÕES DO NOTEBOOK (RÁPIDAS):
# 1. ✅ Max_new_tokens=100-150 (mais rápido)
# 2. ✅ Temperature=0.3-0.5 (menos diversidade, mais velocidade)
# 3. ✅ Top_p=0.8 (menos opções = mais rápido)
# 4. ✅ Prompt conciso e direto
# 5. ✅ Verificação adequada de dispositivo
# 6. ✅ Torch.no_grad() para economia de memória
#
# 🎯 CONFIGURAÇÃO OTIMIZADA RECOMENDADA:
#    max_new_tokens: 100
#    temperature: 0.3
#    top_p: 0.8
#    do_sample: True
#    num_beams: 1
#    early_stopping: True
#    pad_token_id: auto
#    eos_token_id: auto
#
# 🏃‍♂️ DEMONSTRAÇÃO: CONFIGURAÇÃO RÁPIDA VS LENTA
# =======================================================
#
# 🐌 LENTA (atual backend):
#    max_new_tokens: 512
#    temperature: 0.7
#    top_p: 0.9
#    do_sample: True
#
# ⚡ RÁPIDA (otimizada):
#    max_new_tokens: 50
#    temperature: 0.3
#    top_p: 0.8
#    do_sample: True
#
# 🚀 ULTRA RÁPIDA (greedy):
#    max_new_tokens: 30
#    temperature: 0.1
#    do_sample: False
#
# 💡 RECOMENDAÇÃO PARA BACKEND BU FALA:
#    Use configuração RÁPIDA para respostas médicas
#    Use ULTRA RÁPIDA para emergências
#    Reserve LENTA apenas para conteúdo educativo extenso
#
# 🔧 CRIANDO CONFIGURAÇÃO OTIMIZADA PARA BACKEND
# =======================================================
# ✅ Configuração otimizada salva em: c:\Users\fbg67\Desktop\bufala\gemma3_config_optimized.json
#
# 📋 PARA APLICAR A OTIMIZAÇÃO:
# 1. Pare o backend atual
# 2. Renomeie gemma3_config.json para gemma3_config_backup.json
# 3. Renomeie gemma3_config_optimized.json para gemma3_config.json
# 4. Reinicie o backend
# 5. Teste uma consulta médica - deve ser 5-10x mais rápida!
#
# 🎉 ANÁLISE COMPLETA!
# 💡 Com essas otimizações, o Gemma-3n deve responder em 10-30 segundos
#    em vez de 2-3 minutos como está acontecendo atualmente.
